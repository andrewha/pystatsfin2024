# %% [markdown]
# # Variation of Sample

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
# %matplotlib inline

# %%
# Sample mean and SD keep changing, but always within a certain range
# Population parameters: mu = 10, sigma = 5
# Sample size = 30
Fstsample = pd.DataFrame(np.random.normal(10, 5, size=30))
print('sample mean is ', Fstsample[0].mean())
print('sample SD is ', Fstsample[0].std(ddof=1))
# Out:
# sample mean is  9.52429753001
# sample SD is  5.65773451124

# %% [markdown]
# ## Empirical Distribution of mean

# %%
meanlist = []
# Number of trials = 10_000
for t in range(10_000):
    sample = pd.DataFrame(np.random.normal(10, 5, size=30))
    meanlist.append(sample[0].mean())

# %%
collection = pd.DataFrame()
collection['meanlist'] = meanlist

# %%
collection['meanlist'].hist(bins=100, normed=1, figsize=(15,8));

# %% [markdown]
# ## Sampling from arbritary distribution

# %%
# See what Central Limit Theorem tells us:
# Ff the sample size is large enough, then the sampling distribution of sample mean is approximately normal
# Example:
# apop is not normal, but try to change the sample size from 100 to a larger number. The distribution of sample mean of apop 
# becomes normal.
def plot_sampling_distribution(sample_size):
    samplemeanlist = []
    apop =  pd.DataFrame([1, 0, 1, 0, 1])
    for t in range(10_000):
        sample = apop[0].sample(sample_size, replace=True)  # small sample size
        samplemeanlist.append(sample.mean())

    acollec = pd.DataFrame()
    acollec['meanlist'] = samplemeanlist
    acollec.hist(bins=100, normed=1, figsize=(15, 8));

# %%
plot_sampling_distribution(sample_size=10)

# %%
plot_sampling_distribution(sample_size=100)

# %%
plot_sampling_distribution(sample_size=10_000)
